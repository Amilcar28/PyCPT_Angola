# %% [markdown]
# # PyCPT version 2.7.3
#
# This is an example of a PyCPT Version 2 seasonal climate forecasting workflow. This notebook can be adapted to suit your exact needs through modifications of the code. This notebook uses PyCPT v2 utilities to
#
# 1. download data from the IRI Data Library (through the CPT-DL python library)
# 2. Run bias-correction using the IRI Climate Predictability Tool (through its companion python library, CPT-CORE)
# 3. Plot skills scores and spatial loadings
# 4. Produce a multi-model ensemble forecast by taking the simple average of the bias-corrected members
# 5. Plots skill scores, deterministic forecasts, probabilistic forecasts, and exceedance probabilities for this NextGen MME forecast.
#
# PyCPT Version 2 was primarily designed and implemented by Kyle Hall.
#
# ## Function documentation
# To get help on a function, e.g. `pycpt.setup`, run the following command in a new cell:
# ```
# pycpt.setup?
# ```
# To see the function's source code, use two question marks instead of one.

# %% [markdown]
# #### Imports - This cell imports PyCPTv2 libraries

# %%
import pycpt
import packaging
min_version = '2.6.1'
assert packaging.version.parse(pycpt.__version__) >= packaging.version.parse(min_version), f'This notebook requires version {min_version} or higher of the pycpt library, but you have version {pycpt.__version__}. Please close the notebook, update your environment, and load the notebook again. See https://iri-pycpt.github.io/installation/'

import cptdl as dl 
from cptextras import get_colors_bars
import datetime as dt
import numpy as np
from pathlib import Path
import xarray as xr

# %% [markdown]
# #### Define case directory
# The directory where inputs, outputs, and figures generated by this notebook will be stored.

# %%
case_dir = Path.home() / "Desktop/PyCPT" / "Sazonal_2024"

# %% [markdown]
# #### Parameters - This cell defines the parameters of your CPT analysis

# %%
MOS = 'CCA' # must be one of 'CCA', 'PCR'

# Use dl.observations.keys() to see all options for predictand 
# and dl.hindcasts.keys() to see all options for predictors.
# Make sure your first_year & final_year are compatible with 
# your selections for your predictors and predictands.
predictor_names = [ "SPEAR.PRCP", "CCSM4.PRCP"]
predictand_name = 'UCSB.PRCP'

# To download predictand observations from the Data Library, set
#
#   local_predictand_file = None
#
# To read predictand data from a local file instead,
# set local_predictand_file to the full pathname of the file. e.g.
#
#   local_predictand_file = "/home/aaron/src/pycpt_notebooks/obs_PRCP_Oct-Dec.tsv"
#
# The file should be formatted according to the following guidelines:
#https://cpthelp.iri.columbia.edu/CPT_use_input_gridded.html7
local_predictand_file = None


download_args = { 
    # 'fdate':
    #   The initialization date of the model forecasts / hindcasts.
    #   This field is defined by a python datetime.datetime object,
    #   for example: dt.datetime(2022, 5, 1) # YYYY, MM, DD as integers
    #   The year field is only used for forecasts, otherwise ignored.
    #   The day field is only used in subseasonal forecasts, otherwise ignored.
    #   The month field is an integer representing a month - ie, May=5.
    'fdate':  dt.datetime(2024, 5, 1),

    # 'first_year':
    #   The first year of hindcasts you want. **NOT ALL MODELS HAVE ALL YEARS**.
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   This field is defined by a python integer representing a year, e.g. 1993.
    'first_year': 1991,  

    # 'final_year':
    #   The final year of hindcasts you want. **NOT ALL MODELS HAVE ALL YEARS**.
    #   Double check that your model has hindcast data for all years in [first_year, final_year].
    #   This field is defined by a python integer representing a year, e.g. 2016.
    'final_year': 2020,  

    # 'target': 
    #   Mmm-Mmm indicating the months included in the target period of the forecast. 
    #   This field is defined by a python string, with two three-letter month name abbreviations 
    #   whose first letters are capitalized, and all other letters are lowercase
    #   and who are separated by a dash character. 
    #   For example, if you wanted a JJA target period, you would use 'Jun-Aug'.
    'target': 'Jun-Aug',

    # 'predictor_extent':
    #   The geographic bounding box of the climate model data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictor_extent': {
        'east':  284,
        'west': 142, 
        'north': 50,
        'south': -62, 
      }, 

    # 'predictand_extent':
    #   The geographic bounding box of the observation data you want to download.
    #   This field is defined by a python dictionary with the keys "north", "south",
    #   "east", and "west", each of which maps to a python integer representing the 
    #   edge of a bounding box. i.e., "north" will be the northernmost boundary,
    #   "south" the southernmost boundary.
    #   Example: {"north": 90, "south": -90, "east": 0, "west": 180}
    'predictand_extent': {
        'east':  24.5,
        'west': 10.5,  
        'north': -3.5,  
        'south': -18.5, 
      },

    # 'filetype':
    #   The filetype to be downloaded. for now, it saves a lot of headache just to set this equal
    #   to 'cptv10.tsv' which is a boutique plain-text CPT filetype based on .tsv + metadata.
    'filetype': 'cptv10.tsv'
}

cpt_args = { 
    'transform_predictand': None,  # transformation to apply to the predictand dataset - None, 'Empirical', 'Gamma'
    'tailoring': None,  # tailoring None, 'Anomaly'
    'cca_modes': (1,3), # minimum and maximum of allowed CCA modes 
    'x_eof_modes': (1,8), # minimum and maximum of allowed X Principal Componenets 
    'y_eof_modes': (1,6), # minimum and maximum of allowed Y Principal Components 
    'validation': 'crossvalidation', # the type of validation to use; only 'crossvalidation' is supported for now
    'drymask': False, #whether or not to use a drymask of -999
    'scree': True, # whether or not to save % explained variance for eof modes
    'crossvalidation_window': 5,  # number of samples to leave out in each cross-validation step 
    'synchronous_predictors': True, # whether or not we are using 'synchronous predictors'
}

# %% [markdown]
# Set `force_download = False` to avoid re-downloading files you have already downloaded. Note: if you have changed anything in `download_args` since the data were last downloaded, you must set `force_download = True`, otherwise you will use the old data instead of the new.

# %%
force_download = True

# %%
domain_dir = pycpt.setup(case_dir, download_args["predictor_extent"])
# Out:
# Input data will be saved in /home/inamet/Desktop/PyCPT/Sazonal_2024/142W-284E_to_-62S-50N/data
# Figures will be saved in /home/inamet/Desktop/PyCPT/Sazonal_2024/142W-284E_to_-62S-50N/figures
# Output will be saved in /home/inamet/Desktop/PyCPT/Sazonal_2024/142W-284E_to_-62S-50N/output

# %% [markdown]
# #### Visualize predictor and predictand domains

# %%
pycpt.plot_domains(download_args['predictor_extent'], download_args['predictand_extent'])
# Out:
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:451: UserWarning: The .xlabels_top attribute is deprecated. Please use .top_labels to toggle visibility instead.
#   warnings.warn('The .xlabels_top attribute is deprecated. Please '
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/cartopy/mpl/gridliner.py:475: UserWarning: The .ylabels_left attribute is deprecated. Please use .left_labels to toggle visibility instead.
#   warnings.warn('The .ylabels_left attribute is deprecated. Please '

# %% [markdown]
# #### Download Observations, Hindcasts, and Forecasts from IRI Data Library

# %%
Y, hindcast_data, forecast_data = pycpt.download_data(predictand_name, local_predictand_file, predictor_names, download_args, domain_dir, force_download)
# Out:
# Downloading SPEAR.PRCP_f2024
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-SPEAR/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/S/%280000%201%20May%202024%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-62/50/RANGEEDGES/X/142/284/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
#
# DOWNLOADING: [*************************] (232 KB) 0:00:02.235876
# Downloading CCSM4.PRCP_f2024
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.prec/S/%280000%201%20May%202024%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-62/50/RANGEEDGES/X/142/284/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
#
# DOWNLOADING: [*************************] (233 KB) 0:00:03.397970
# Downloading UCSB.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.UCSB/.CHIRPS/.v2p0/.daily-improved/.global/.0p25/.prcp/92/mul/T/(1%20Jan%201991)/(31%20Dec%202020)/RANGE/T/%28Jun-Aug%201991-2020%29/seasonalAverage/Y/%28-18.5%29/%28-3.5%29/RANGEEDGES/X/%2810.5%29/%2824.5%29/RANGEEDGES/-999/setmissing_value/%5BX/Y%5D%5BT%5Dcptv10.tsv
#
# DOWNLOADING: [*************************] (1456 KB) 0:00:38.781662
# Downloading SPEAR.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.GFDL-SPEAR/.HINDCAST/.MONTHLY/.prec/%5BM%5D/average/S/first/(1%20Nov%202020)/RANGEEDGES/SOURCES/.Models/.NMME/.GFDL-SPEAR/.FORECAST/.MONTHLY/.prec/%5BM%5D/average/appendstream/S/%280000%201%20May%201991-2020%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-62/50/RANGEEDGES/X/142/284/RANGEEDGES/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
#
# DOWNLOADING: [*************************] (6898 KB) 0:01:41.702225
# Downloading CCSM4.PRCP
# URL: https://iridl.ldeo.columbia.edu/SOURCES/.Models/.NMME/.COLA-RSMAS-CCSM4/.MONTHLY/.prec/S/%280000%201%20May%201991-2020%29/VALUES/L/1.5/3.5/RANGEEDGES/%5BL%5D//keepgrids/average/Y/-62/50/RANGEEDGES/X/142/284/RANGEEDGES/%5BM%5D/average/92/mul/-999/setmissing_value/%5BX/Y%5D%5BL/S/add%5D/cptv10.tsv
#
# DOWNLOADING: [*************************] (6898 KB) 0:01:09.788591

# %% [markdown]
# #### Perform CPT Analysis
# Set `interactive = True` to see detailed output from CPT.

# %%
interactive = False

# %%
hcsts, fcsts, skill, pxs, pys = pycpt.evaluate_models(hindcast_data, MOS, Y, forecast_data, cpt_args, domain_dir, predictor_names, interactive)

# %% [markdown]
# #### Plot skill of individual models
#
# Deterministic skill metrics:
# - pearson
# - spearman
# - two_alternative_forced_choice
# - roc_area_below_normal (Area under ROC curve for Below Normal category)
# - roc_area_above_normal (Area under ROC curve for Above Normal category)
#
# Probabilistic skill metrics (in sample):
# - generalized_roc
# - rank_probability_skill_score

# %%
skill_metrics = [
    "pearson",
    "spearman",
    "two_alternative_forced_choice",
    "roc_area_below_normal",
    "roc_area_above_normal",
]

# %%
pycpt.plot_skill(predictor_names, skill, MOS, domain_dir, skill_metrics)
# Out:
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# #### Plot EOF Modes

# %%
pycpt.plot_eof_modes(MOS, predictor_names, pxs, pys, domain_dir)
# Out:
# SPEAR.PRCP: EOF 1
# SPEAR.PRCP: EOF 2
# SPEAR.PRCP: EOF 3
# SPEAR.PRCP: EOF 4
# SPEAR.PRCP: EOF 5
# CCSM4.PRCP: EOF 1
# CCSM4.PRCP: EOF 2
# CCSM4.PRCP: EOF 3
# CCSM4.PRCP: EOF 4
# CCSM4.PRCP: EOF 5

# %% [markdown]
# #### Plot CCA Modes

# %%
pycpt.plot_cca_modes(MOS, predictor_names, pxs, pys, domain_dir)
# Out:
# SPEAR.PRCP: CCA MODE 1 - Canonical Correlation = 0.68
# SPEAR.PRCP: CCA MODE 2 - Canonical Correlation = nan
# SPEAR.PRCP: CCA MODE 3 - Canonical Correlation = nan
# CCSM4.PRCP: CCA MODE 1 - Canonical Correlation = 0.79
# CCSM4.PRCP: CCA MODE 2 - Canonical Correlation = 0.68
# CCSM4.PRCP: CCA MODE 3 - Canonical Correlation = 0.49

# %% [markdown]
# #### Plot Forecasts

# %%
pycpt.plot_forecasts(cpt_args, predictand_name, fcsts, domain_dir, predictor_names, MOS)

# %% [markdown]
# # Multi-Model Ensemble

# %% [markdown]
# Choose which models to include in the MME, e.g.
# ```
# ensemble = ['CFSv2.PRCP','SEAS5.PRCP']
# ```

# %%
ensemble = predictor_names

# %%
det_fcst, pr_fcst, pev_fcst, nextgen_skill = pycpt.construct_mme(fcsts, hcsts, Y, ensemble, predictor_names, cpt_args, domain_dir)

# %% [markdown]
# #### Plot MME Forecast Skill
#
# Deterministic metrics: pearson, spearman, 2afc, roc_below, roc_above
#
# Probabilistic metrics: generalized_roc, rank_probability_skill_score
#
# e.g.
# ```
# skill_metrics = ["spearman", "generalized_roc"]
# ```

# %%
skill_metrics = [
    "spearman",
    "2afc",
    "generalized_roc",
    "rank_probability_skill_score",
]

# %%
pycpt.plot_mme_skill(predictor_names, nextgen_skill, MOS, domain_dir, skill_metrics)

# %% [markdown]
# #### Plot MME Forecasts

# %%
pycpt.plot_mme_forecasts(cpt_args, predictand_name, pr_fcst, MOS, domain_dir, det_fcst)

# %% [markdown]
# #### Construct MME Flexible Forecasts (full PDF)

# %% [markdown]
# If `isPercentile` is `True`, the threshold is a percentile (e.g., 0.5)
# else in the unit of the predictand (e.g., mm, degC, ...)

# %%
threshold = 0.5
isPercentile = True

# %%
exceedance_prob, fcst_scale, climo_scale, fcst_mu, climo_mu, Y2, ntrain, transformed_threshold = pycpt.construct_flex_fcst(MOS, cpt_args, det_fcst, threshold, isPercentile, Y, pev_fcst)
# Out:
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1563: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a,
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2152: RuntimeWarning: divide by zero encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# /home/inamet/anaconda3/envs/pycpt-2.8.2/lib/python3.10/site-packages/scipy/stats/_distn_infrastructure.py:2152: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)

# %% [markdown]
# #### Plot Flexible MME Forecasts
#
# Choose a gridpoint within the predictand domain to plot the forecast and climatological probability of exceedance and PDF curves. If set to None, the centroid of the predictand domain will be used.
#
# If you want to use a different color bar than the one used by default, assign the name of the desired color bar to the variable **color_bar**, None value will use the default color bars. If you are unaware of the available color bars, run `get_colors_bars()`.

# %%
point_latitude = None
point_longitude = None
color_bar = None

# %%
pycpt.plot_mme_flex_forecasts(predictand_name, exceedance_prob, point_latitude, point_longitude, download_args["predictand_extent"], transformed_threshold, fcst_scale, climo_scale, fcst_mu, climo_mu, Y2, cpt_args['transform_predictand'], ntrain, Y, MOS, domain_dir,color_bar)

# %% [markdown]
# These final cells record information about the python environment that will be useful if we need to reproduce this configuration in the future.

# %%
# !conda list
# Out:
# # packages in environment at /home/inamet/anaconda3/envs/pycpt-2.8.2:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# alsa-lib                  1.2.10               hd590300_0    conda-forge
# anyio                     3.7.1              pyhd8ed1ab_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0                   pypi_0    pypi
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# attr                      2.5.1                h166bdaf_1    conda-forge
# attrs                     23.2.0             pyh71513ae_0    conda-forge
# aws-c-auth                0.7.16               h70caa3e_0    conda-forge
# aws-c-cal                 0.6.9                h14ec70c_3    conda-forge
# aws-c-common              0.9.12               hd590300_0    conda-forge
# aws-c-compression         0.2.17               h572eabf_8    conda-forge
# aws-c-event-stream        0.4.2                h17cd1f3_0    conda-forge
# aws-c-http                0.8.0                hc6da83f_5    conda-forge
# aws-c-io                  0.14.3               h3c8c088_1    conda-forge
# aws-c-mqtt                0.10.2               h0ef3971_0    conda-forge
# aws-c-s3                  0.5.1                h2910485_1    conda-forge
# aws-c-sdkutils            0.1.14               h572eabf_0    conda-forge
# aws-checksums             0.1.17               h572eabf_7    conda-forge
# aws-crt-cpp               0.26.2               ha623a59_3    conda-forge
# aws-sdk-cpp               1.11.267             h0bb408c_0    conda-forge
# beautifulsoup4            4.12.3             pyha770c72_0    conda-forge
# bleach                    6.1.0              pyhd8ed1ab_0    conda-forge
# blosc                     1.21.5               h0f2a231_0    conda-forge
# bokeh                     3.3.4              pyhd8ed1ab_0    conda-forge
# bottleneck                1.3.7                    pypi_0    pypi
# brotli                    1.1.0                    pypi_0    pypi
# brotli-bin                1.1.0                hd590300_1    conda-forge
# brotli-python             1.1.0           py310hc6cd4ac_1    conda-forge
# bzip2                     1.0.8                hd590300_5    conda-forge
# c-ares                    1.26.0               hd590300_0    conda-forge
# ca-certificates           2024.2.2             hbcca054_0    conda-forge
# cairo                     1.18.0               h3faef2a_0    conda-forge
# cartopy                   0.22.0                   pypi_0    pypi
# certifi                   2024.2.2           pyhd8ed1ab_0    conda-forge
# cffi                      1.16.0                   pypi_0    pypi
# cftime                    1.6.3                    pypi_0    pypi
# charset-normalizer        3.3.2              pyhd8ed1ab_0    conda-forge
# click                     8.1.7           unix_pyh707e725_0    conda-forge
# cloudpickle               3.0.0              pyhd8ed1ab_0    conda-forge
# comm                      0.2.1              pyhd8ed1ab_0    conda-forge
# contourpy                 1.2.0                    pypi_0    pypi
# cptbin                    17.8.3               h3d0eb6f_0    iri-nextgen
# cptcore                   2.2.0                      py_1    iri-nextgen
# cptdl                     1.1.5                      py_0    iri-nextgen
# cptextras                 1.2.0                      py_0    iri-nextgen
# cptio                     1.2.0                      py_0    iri-nextgen
# cycler                    0.12.1             pyhd8ed1ab_0    conda-forge
# cytoolz                   0.12.3                   pypi_0    pypi
# dask                      2024.2.0           pyhd8ed1ab_0    conda-forge
# dask-core                 2024.2.0           pyhd8ed1ab_0    conda-forge
# dbus                      1.13.6               h5008d03_3    conda-forge
# debugpy                   1.8.1                    pypi_0    pypi
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# distributed               2024.2.0           pyhd8ed1ab_0    conda-forge
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# exceptiongroup            1.2.0              pyhd8ed1ab_2    conda-forge
# executing                 2.0.1              pyhd8ed1ab_0    conda-forge
# expat                     2.5.0                hcb278e6_1    conda-forge
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 h77eed37_1    conda-forge
# fontconfig                2.14.2               h14ed4e7_0    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.49.0                   pypi_0    pypi
# freetype                  2.12.1               h267a509_2    conda-forge
# fsspec                    2024.2.0           pyhca7485f_0    conda-forge
# ftputil                   5.1.0              pyhd8ed1ab_0    conda-forge
# geos                      3.12.1               h59595ed_0    conda-forge
# gettext                   0.21.1               h27087fc_0    conda-forge
# gflags                    2.2.2             he1b5a44_1004    conda-forge
# glib                      2.78.4               hfc55251_0    conda-forge
# glib-tools                2.78.4               hfc55251_0    conda-forge
# glog                      0.6.0                h6f12383_0    conda-forge
# graphite2                 1.3.13            h58526e2_1001    conda-forge
# gst-plugins-base          1.22.9               h8e1006c_0    conda-forge
# gstreamer                 1.22.9               h98fc4e7_0    conda-forge
# harfbuzz                  8.3.0                h3d44ed6_0    conda-forge
# hdf4                      4.2.15               h2a13503_7    conda-forge
# hdf5                      1.14.3          nompi_h4f84152_100    conda-forge
# icu                       73.2                 h59595ed_0    conda-forge
# idna                      3.6                pyhd8ed1ab_0    conda-forge
# importlib-metadata        7.0.1              pyha770c72_0    conda-forge
# importlib_metadata        7.0.1                hd8ed1ab_0    conda-forge
# importlib_resources       6.1.1              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.29.2             pyhd33586a_0    conda-forge
# ipython                   8.21.0             pyh707e725_0    conda-forge
# ipython_genutils          0.2.0                      py_1    conda-forge
# ipywidgets                8.1.2              pyhd8ed1ab_0    conda-forge
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# jinja2                    3.1.3              pyhd8ed1ab_0    conda-forge
# joblib                    1.3.2              pyhd8ed1ab_0    conda-forge
# jsonschema                4.21.1             pyhd8ed1ab_0    conda-forge
# jsonschema-specifications 2023.12.1          pyhd8ed1ab_0    conda-forge
# jupyter                   1.0.0             pyhd8ed1ab_10    conda-forge
# jupyter-core              5.7.1                    pypi_0    pypi
# jupyter_client            7.3.4              pyhd8ed1ab_0    conda-forge
# jupyter_console           6.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.1           py310hff52083_0    conda-forge
# jupyter_server            1.24.0             pyhd8ed1ab_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_1    conda-forge
# jupyterlab_widgets        3.0.10             pyhd8ed1ab_0    conda-forge
# keyutils                  1.6.1                h166bdaf_0    conda-forge
# kiwisolver                1.4.5                    pypi_0    pypi
# krb5                      1.21.2               h659d440_0    conda-forge
# lame                      3.100             h166bdaf_1003    conda-forge
# lcms2                     2.16                 hb7c19ff_0    conda-forge
# ld_impl_linux-64          2.40                 h41732ed_0    conda-forge
# lerc                      4.0.0                h27087fc_0    conda-forge
# libabseil                 20230802.1      cxx17_h59595ed_0    conda-forge
# libaec                    1.1.2                h59595ed_1    conda-forge
# libarrow                  15.0.0           h49c8883_4_cpu    conda-forge
# libarrow-acero            15.0.0           h59595ed_4_cpu    conda-forge
# libarrow-dataset          15.0.0           h59595ed_4_cpu    conda-forge
# libarrow-flight           15.0.0           hdc44a87_4_cpu    conda-forge
# libarrow-flight-sql       15.0.0           hfbc7f12_4_cpu    conda-forge
# libarrow-gandiva          15.0.0           h308e607_4_cpu    conda-forge
# libarrow-substrait        15.0.0           hfbc7f12_4_cpu    conda-forge
# libblas                   3.9.0           21_linux64_openblas    conda-forge
# libbrotlicommon           1.1.0                hd590300_1    conda-forge
# libbrotlidec              1.1.0                hd590300_1    conda-forge
# libbrotlienc              1.1.0                hd590300_1    conda-forge
# libcap                    2.69                 h0f662aa_0    conda-forge
# libcblas                  3.9.0           21_linux64_openblas    conda-forge
# libclang                  15.0.7          default_hb11cfb5_4    conda-forge
# libclang13                15.0.7          default_ha2b6cf4_4    conda-forge
# libcrc32c                 1.1.2                h9c3ff4c_0    conda-forge
# libcups                   2.3.3                h4637d8d_4    conda-forge
# libcurl                   8.5.0                hca28451_0    conda-forge
# libdeflate                1.19                 hd590300_0    conda-forge
# libedit                   3.1.20191231         he28a2e2_2    conda-forge
# libev                     4.33                 hd590300_2    conda-forge
# libevent                  2.1.12               hf998b51_1    conda-forge
# libexpat                  2.5.0                hcb278e6_1    conda-forge
# libffi                    3.4.2                h7f98852_5    conda-forge
# libflac                   1.4.3                h59595ed_0    conda-forge
# libgcc-ng                 13.2.0               h807b86a_5    conda-forge
# libgcrypt                 1.10.3               hd590300_0    conda-forge
# libgfortran-ng            13.2.0               h69a702a_5    conda-forge
# libgfortran5              13.2.0               ha4646dd_5    conda-forge
# libglib                   2.78.4               h783c2da_0    conda-forge
# libgomp                   13.2.0               h807b86a_5    conda-forge
# libgoogle-cloud           2.12.0               hef10d8f_5    conda-forge
# libgpg-error              1.47                 h71f35ed_0    conda-forge
# libgrpc                   1.60.1               h74775cd_0    conda-forge
# libiconv                  1.17                 hd590300_2    conda-forge
# libjpeg-turbo             3.0.0                hd590300_1    conda-forge
# liblapack                 3.9.0           21_linux64_openblas    conda-forge
# libllvm15                 15.0.7               hb3ce162_4    conda-forge
# libnetcdf                 4.9.2           nompi_h9612171_113    conda-forge
# libnghttp2                1.58.0               h47da74e_1    conda-forge
# libnl                     3.9.0                hd590300_0    conda-forge
# libnsl                    2.0.1                hd590300_0    conda-forge
# libnuma                   2.0.16               h0b41bf4_1    conda-forge
# libogg                    1.3.4                h7f98852_1    conda-forge
# libopenblas               0.3.26          pthreads_h413a1c8_0    conda-forge
# libopus                   1.3.1                h7f98852_1    conda-forge
# libparquet                15.0.0           h352af49_4_cpu    conda-forge
# libpng                    1.6.42               h2797004_0    conda-forge
# libpq                     16.2                 h33b98f1_0    conda-forge
# libprotobuf               4.25.1               hf27288f_2    conda-forge
# libre2-11                 2023.06.02           h7a70373_0    conda-forge
# libsndfile                1.2.2                hc60ed4a_1    conda-forge
# libsodium                 1.0.18               h36c2ea0_1    conda-forge
# libsqlite                 3.45.1               h2797004_0    conda-forge
# libssh2                   1.11.0               h0841786_0    conda-forge
# libstdcxx-ng              13.2.0               h7e041cc_5    conda-forge
# libsystemd0               255                  h3516f8a_0    conda-forge
# libthrift                 0.19.0               hb90f79a_1    conda-forge
# libtiff                   4.6.0                ha9c0a0a_2    conda-forge
# libutf8proc               2.8.0                h166bdaf_0    conda-forge
# libuuid                   2.38.1               h0b41bf4_0    conda-forge
# libvorbis                 1.3.7                h9c3ff4c_0    conda-forge
# libwebp-base              1.3.2                hd590300_0    conda-forge
# libxcb                    1.15                 h0b41bf4_0    conda-forge
# libxcrypt                 4.4.36               hd590300_1    conda-forge
# libxkbcommon              1.6.0                hd429924_1    conda-forge
# libxml2                   2.12.5               h232c23b_0    conda-forge
# libzip                    1.10.1               h2629f0a_3    conda-forge
# libzlib                   1.2.13               hd590300_5    conda-forge
# locket                    1.0.0              pyhd8ed1ab_0    conda-forge
# lz4                       4.3.3                    pypi_0    pypi
# lz4-c                     1.9.4                hcb278e6_0    conda-forge
# markupsafe                2.1.5                    pypi_0    pypi
# matplotlib                3.7.1                    pypi_0    pypi
# matplotlib-base           3.7.1           py310he60537e_0    conda-forge
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge
# mistune                   3.0.2              pyhd8ed1ab_0    conda-forge
# mpg123                    1.32.4               h59595ed_0    conda-forge
# msgpack                   1.0.7                    pypi_0    pypi
# msgpack-python            1.0.7           py310hd41b1e2_0    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# mysql-common              8.0.33               hf1915f5_6    conda-forge
# mysql-libs                8.0.33               hca2cd23_6    conda-forge
# nbclassic                 1.0.0              pyhb4ecaf3_1    conda-forge
# nbclient                  0.8.0              pyhd8ed1ab_0    conda-forge
# nbconvert                 7.16.1             pyhd8ed1ab_0    conda-forge
# nbconvert-core            7.16.1             pyhd8ed1ab_0    conda-forge
# nbconvert-pandoc          7.16.1             pyhd8ed1ab_0    conda-forge
# nbformat                  5.9.2              pyhd8ed1ab_0    conda-forge
# ncurses                   6.4                  h59595ed_2    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# netcdf4                   1.6.5                    pypi_0    pypi
# notebook                  6.5.6              pyha770c72_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_0    conda-forge
# nspr                      4.35                 h27087fc_0    conda-forge
# nss                       3.98                 h1d7d5a4_0    conda-forge
# numpy                     1.26.4                   pypi_0    pypi
# openjpeg                  2.5.0                h488ebb8_3    conda-forge
# openssl                   3.2.1                hd590300_0    conda-forge
# orc                       1.9.2                h7829240_1    conda-forge
# packaging                 23.2               pyhd8ed1ab_0    conda-forge
# pandas                    2.2.0                    pypi_0    pypi
# pandoc                    3.1.12.1             ha770c72_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# parso                     0.8.3              pyhd8ed1ab_0    conda-forge
# partd                     1.4.1              pyhd8ed1ab_0    conda-forge
# patsy                     0.5.6              pyhd8ed1ab_0    conda-forge
# pcre2                     10.42                hcad00b1_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    10.2.0                   pypi_0    pypi
# pip                       24.0               pyhd8ed1ab_0    conda-forge
# pixman                    0.43.2               h59595ed_0    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_1    conda-forge
# platformdirs              4.2.0              pyhd8ed1ab_0    conda-forge
# ply                       3.11                       py_1    conda-forge
# proj                      9.3.1                h1d62c97_0    conda-forge
# prometheus_client         0.20.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.42             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.42               hd8ed1ab_0    conda-forge
# psutil                    5.9.8                    pypi_0    pypi
# pthread-stubs             0.4               h36c2ea0_1001    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pulseaudio-client         16.1                 hb77b528_5    conda-forge
# pure_eval                 0.2.2              pyhd8ed1ab_0    conda-forge
# pyarrow                   15.0.0                   pypi_0    pypi
# pyarrow-hotfix            0.6                pyhd8ed1ab_0    conda-forge
# pycparser                 2.21               pyhd8ed1ab_0    conda-forge
# pycpt                     2.8.1                      py_0    iri-nextgen
# pygments                  2.17.2             pyhd8ed1ab_0    conda-forge
# pyparsing                 3.1.1              pyhd8ed1ab_0    conda-forge
# pyproj                    3.6.1                    pypi_0    pypi
# pyqt                      5.15.9          py310h04931ad_5    conda-forge
# pyqt5                     5.15.9                   pypi_0    pypi
# pyqt5-sip                 12.12.2                  pypi_0    pypi
# pyshp                     2.3.1              pyhd8ed1ab_0    conda-forge
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.10.13         hd12c33a_1_cpython    conda-forge
# python-dateutil           2.8.2              pyhd8ed1ab_0    conda-forge
# python-fastjsonschema     2.19.1             pyhd8ed1ab_0    conda-forge
# python-tzdata             2024.1             pyhd8ed1ab_0    conda-forge
# python_abi                3.10                    4_cp310    conda-forge
# pytz                      2024.1             pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0.1                    pypi_0    pypi
# pyzmq                     24.0.1                   pypi_0    pypi
# qt-main                   5.15.8              h5810be5_19    conda-forge
# qtconsole-base            5.5.1              pyha770c72_0    conda-forge
# qtpy                      2.4.1              pyhd8ed1ab_0    conda-forge
# rdma-core                 50.0                 hd3aeb46_0    conda-forge
# re2                       2023.06.02           h2873b5e_0    conda-forge
# readline                  8.2                  h8228510_1    conda-forge
# referencing               0.33.0             pyhd8ed1ab_0    conda-forge
# requests                  2.31.0             pyhd8ed1ab_0    conda-forge
# rpds-py                   0.18.0                   pypi_0    pypi
# s2n                       1.4.3                h06160fa_0    conda-forge
# scikit-learn              1.4.1.post1              pypi_0    pypi
# scipy                     1.12.0                   pypi_0    pypi
# send2trash                1.8.2              pyh41d4057_0    conda-forge
# setuptools                69.1.0             pyhd8ed1ab_1    conda-forge
# shapely                   2.0.3                    pypi_0    pypi
# sip                       6.7.12                   pypi_0    pypi
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# snappy                    1.1.10               h9fff704_0    conda-forge
# sniffio                   1.3.0              pyhd8ed1ab_0    conda-forge
# sortedcontainers          2.4.0              pyhd8ed1ab_0    conda-forge
# soupsieve                 2.5                pyhd8ed1ab_1    conda-forge
# sqlite                    3.45.1               h2c6b66d_0    conda-forge
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.14.1                   pypi_0    pypi
# tblib                     3.0.0              pyhd8ed1ab_0    conda-forge
# terminado                 0.18.0             pyh0d859eb_0    conda-forge
# threadpoolctl             3.3.0              pyhc1e730c_0    conda-forge
# tinycss2                  1.2.1              pyhd8ed1ab_0    conda-forge
# tk                        8.6.13          noxft_h4845f30_101    conda-forge
# toml                      0.10.2             pyhd8ed1ab_0    conda-forge
# tomli                     2.0.1              pyhd8ed1ab_0    conda-forge
# toolz                     0.12.1             pyhd8ed1ab_0    conda-forge
# tornado                   6.1                      pypi_0    pypi
# traitlets                 5.14.1             pyhd8ed1ab_0    conda-forge
# typing-extensions         4.9.0                hd8ed1ab_0    conda-forge
# typing_extensions         4.9.0              pyha770c72_0    conda-forge
# tzdata                    2024a                h0c530f3_0    conda-forge
# ucx                       1.15.0               h75e419f_3    conda-forge
# unicodedata2              15.1.0                   pypi_0    pypi
# urllib3                   1.26.18            pyhd8ed1ab_0    conda-forge
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_2    conda-forge
# websocket-client          1.7.0              pyhd8ed1ab_0    conda-forge
# wheel                     0.42.0             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.10             pyhd8ed1ab_0    conda-forge
# xarray                    2024.2.0           pyhd8ed1ab_0    conda-forge
# xcb-util                  0.4.0                hd590300_1    conda-forge
# xcb-util-image            0.4.0                h8ee46fc_1    conda-forge
# xcb-util-keysyms          0.4.0                h8ee46fc_1    conda-forge
# xcb-util-renderutil       0.3.9                hd590300_1    conda-forge
# xcb-util-wm               0.4.1                h8ee46fc_1    conda-forge
# xkeyboard-config          2.41                 hd590300_0    conda-forge
# xorg-kbproto              1.0.7             h7f98852_1002    conda-forge
# xorg-libice               1.1.1                hd590300_0    conda-forge
# xorg-libsm                1.2.4                h7391055_0    conda-forge
# xorg-libx11               1.8.7                h8ee46fc_0    conda-forge
# xorg-libxau               1.0.11               hd590300_0    conda-forge
# xorg-libxdmcp             1.1.3                h7f98852_0    conda-forge
# xorg-libxext              1.3.4                h0b41bf4_2    conda-forge
# xorg-libxrender           0.9.11               hd590300_0    conda-forge
# xorg-renderproto          0.11.1            h7f98852_1002    conda-forge
# xorg-xextproto            7.3.0             h0b41bf4_1003    conda-forge
# xorg-xf86vidmodeproto     2.3.1             h7f98852_1002    conda-forge
# xorg-xproto               7.0.31            h7f98852_1007    conda-forge
# xyzservices               2023.10.1          pyhd8ed1ab_0    conda-forge
# xz                        5.2.6                h166bdaf_0    conda-forge
# yaml                      0.2.5                h7f98852_2    conda-forge
# zeromq                    4.3.5                h59595ed_0    conda-forge
# zict                      3.0.0              pyhd8ed1ab_0    conda-forge
# zipp                      3.17.0             pyhd8ed1ab_0    conda-forge
# zlib                      1.2.13               hd590300_5    conda-forge
# zstd                      1.5.5                hfc55251_0    conda-forge

# %%
# !conda list --explicit
# Out:
# # This file may be used to create an environment using:
# # $ conda create --name <env> --file <this file>
# # platform: linux-64
# @EXPLICIT
# https://conda.anaconda.org/conda-forge/linux-64/_libgcc_mutex-0.1-conda_forge.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/ca-certificates-2024.2.2-hbcca054_0.conda
# https://conda.anaconda.org/conda-forge/noarch/font-ttf-dejavu-sans-mono-2.37-hab24e00_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/font-ttf-inconsolata-3.000-h77eed37_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/font-ttf-source-code-pro-2.038-h77eed37_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/font-ttf-ubuntu-0.83-h77eed37_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/ld_impl_linux-64-2.40-h41732ed_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libstdcxx-ng-13.2.0-h7e041cc_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pandoc-3.1.12.1-ha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/python_abi-3.10-4_cp310.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/tzdata-2024a-h0c530f3_0.conda
# https://conda.anaconda.org/conda-forge/noarch/fonts-conda-forge-1-0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgomp-13.2.0-h807b86a_5.conda
# https://conda.anaconda.org/conda-forge/linux-64/_openmp_mutex-4.5-2_gnu.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/fonts-conda-ecosystem-1-0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgcc-ng-13.2.0-h807b86a_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/alsa-lib-1.2.10-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/attr-2.5.1-h166bdaf_1.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-common-0.9.12-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/bzip2-1.0.8-hd590300_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/c-ares-1.26.0-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/geos-3.12.1-h59595ed_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/gettext-0.21.1-h27087fc_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/gflags-2.2.2-he1b5a44_1004.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/graphite2-1.3.13-h58526e2_1001.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/icu-73.2-h59595ed_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/keyutils-1.6.1-h166bdaf_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/lame-3.100-h166bdaf_1003.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/lerc-4.0.0-h27087fc_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libabseil-20230802.1-cxx17_h59595ed_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libaec-1.1.2-h59595ed_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libbrotlicommon-1.1.0-hd590300_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/libcrc32c-1.1.2-h9c3ff4c_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libdeflate-1.19-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/libedit-3.1.20191231-he28a2e2_2.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libev-4.33-hd590300_2.conda
# https://conda.anaconda.org/conda-forge/linux-64/libexpat-2.5.0-hcb278e6_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/libffi-3.4.2-h7f98852_5.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgfortran5-13.2.0-ha4646dd_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libiconv-1.17-hd590300_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libjpeg-turbo-3.0.0-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libnl-3.9.0-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libnsl-2.0.1-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/libnuma-2.0.16-h0b41bf4_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/libogg-1.3.4-h7f98852_1.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/libopus-1.3.1-h7f98852_1.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/libsodium-1.0.18-h36c2ea0_1.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/libutf8proc-2.8.0-h166bdaf_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/libuuid-2.38.1-h0b41bf4_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libwebp-base-1.3.2-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libxcrypt-4.4.36-hd590300_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/libzlib-1.2.13-hd590300_5.conda
# https://conda.anaconda.org/conda-forge/linux-64/lz4-c-1.9.4-hcb278e6_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/mpg123-1.32.4-h59595ed_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/ncurses-6.4-h59595ed_2.conda
# https://conda.anaconda.org/conda-forge/linux-64/nspr-4.35-h27087fc_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/openssl-3.2.1-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pixman-0.43.2-h59595ed_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/pthread-stubs-0.4-h36c2ea0_1001.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/snappy-1.1.10-h9fff704_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-kbproto-1.0.7-h7f98852_1002.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/xorg-libice-1.1.1-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-libxau-1.0.11-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-libxdmcp-1.1.3-h7f98852_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/xorg-renderproto-0.11.1-h7f98852_1002.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/xorg-xextproto-7.3.0-h0b41bf4_1003.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-xf86vidmodeproto-2.3.1-h7f98852_1002.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/xorg-xproto-7.0.31-h7f98852_1007.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/xz-5.2.6-h166bdaf_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/yaml-0.2.5-h7f98852_2.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-cal-0.6.9-h14ec70c_3.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-compression-0.2.17-h572eabf_8.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-sdkutils-0.1.14-h572eabf_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-checksums-0.1.17-h572eabf_7.conda
# https://conda.anaconda.org/conda-forge/linux-64/expat-2.5.0-hcb278e6_1.conda
# https://conda.anaconda.org/conda-forge/linux-64/glog-0.6.0-h6f12383_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/hdf4-4.2.15-h2a13503_7.conda
# https://conda.anaconda.org/conda-forge/linux-64/krb5-1.21.2-h659d440_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libbrotlidec-1.1.0-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libbrotlienc-1.1.0-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libcap-2.69-h0f662aa_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libevent-2.1.12-hf998b51_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libflac-1.4.3-h59595ed_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgfortran-ng-13.2.0-h69a702a_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgpg-error-1.47-h71f35ed_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libnghttp2-1.58.0-h47da74e_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libpng-1.6.42-h2797004_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libprotobuf-4.25.1-hf27288f_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libre2-11-2023.06.02-h7a70373_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libsqlite-3.45.1-h2797004_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/libssh2-1.11.0-h0841786_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/libvorbis-1.3.7-h9c3ff4c_0.tar.bz2
# https://conda.anaconda.org/conda-forge/linux-64/libxcb-1.15-h0b41bf4_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libxml2-2.12.5-h232c23b_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libzip-1.10.1-h2629f0a_3.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/mysql-common-8.0.33-hf1915f5_6.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pcre2-10.42-hcad00b1_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/rdma-core-50.0-hd3aeb46_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/readline-8.2-h8228510_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/s2n-1.4.3-h06160fa_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/tk-8.6.13-noxft_h4845f30_101.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-libsm-1.2.4-h7391055_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/zeromq-4.3.5-h59595ed_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/zlib-1.2.13-hd590300_5.conda
# https://conda.anaconda.org/conda-forge/linux-64/zstd-1.5.5-hfc55251_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-io-0.14.3-h3c8c088_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/blosc-1.21.5-h0f2a231_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/brotli-bin-1.1.0-hd590300_1.conda
# https://conda.anaconda.org/iri-nextgen/linux-64/cptbin-17.8.3-h3d0eb6f_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/freetype-2.12.1-h267a509_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libcups-2.3.3-h4637d8d_4.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libcurl-8.5.0-hca28451_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgcrypt-1.10.3-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libglib-2.78.4-h783c2da_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libllvm15-15.0.7-hb3ce162_4.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libopenblas-0.3.26-pthreads_h413a1c8_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libpq-16.2-h33b98f1_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libsndfile-1.2.2-hc60ed4a_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libthrift-0.19.0-hb90f79a_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libtiff-4.6.0-ha9c0a0a_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/mysql-libs-8.0.33-hca2cd23_6.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/nss-3.98-h1d7d5a4_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/orc-1.9.2-h7829240_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/python-3.10.13-hd12c33a_1_cpython.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/re2-2023.06.02-h2873b5e_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/sqlite-3.45.1-h2c6b66d_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/ucx-1.15.0-h75e419f_3.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xcb-util-0.4.0-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xcb-util-keysyms-0.4.0-h8ee46fc_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xcb-util-renderutil-0.3.9-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xcb-util-wm-0.4.1-h8ee46fc_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xorg-libx11-1.8.7-h8ee46fc_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/attrs-23.2.0-pyh71513ae_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-event-stream-0.4.2-h17cd1f3_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-http-0.8.0-hc6da83f_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/brotli-1.1.0-hd590300_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/brotli-python-1.1.0-py310hc6cd4ac_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/certifi-2024.2.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/charset-normalizer-3.3.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/click-8.1.7-unix_pyh707e725_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/cloudpickle-3.0.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/cycler-0.12.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/dbus-1.13.6-h5008d03_3.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/debugpy-1.8.1-py310hc6cd4ac_0.conda
# https://conda.anaconda.org/conda-forge/noarch/decorator-5.1.1-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/defusedxml-0.7.1-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/entrypoints-0.4-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/exceptiongroup-1.2.0-pyhd8ed1ab_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/executing-2.0.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/fontconfig-2.14.2-h14ed4e7_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/fsspec-2024.2.0-pyhca7485f_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/ftputil-5.1.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/glib-tools-2.78.4-hfc55251_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/hdf5-1.14.3-nompi_h4f84152_100.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/idna-3.6-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/ipython_genutils-0.2.0-py_1.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jupyterlab_widgets-3.0.10-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/kiwisolver-1.4.5-py310hd41b1e2_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/lcms2-2.16-hb7c19ff_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libblas-3.9.0-21_linux64_openblas.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libclang13-15.0.7-default_ha2b6cf4_4.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgrpc-1.60.1-h74775cd_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libsystemd0-255-h3516f8a_0.conda
# https://conda.anaconda.org/conda-forge/noarch/locket-1.0.0-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/lz4-4.3.3-py310h350c4a5_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/markupsafe-2.1.5-py310h2372a71_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/mistune-3.0.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/msgpack-python-1.0.7-py310hd41b1e2_0.conda
# https://conda.anaconda.org/conda-forge/noarch/munkres-1.1.4-pyh9f0ad1d_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/nest-asyncio-1.6.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/openjpeg-2.5.0-h488ebb8_3.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/packaging-23.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/pandocfilters-1.5.0-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/parso-0.8.3-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/pickleshare-0.7.5-py_1003.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pkgutil-resolve-name-1.3.10-pyhd8ed1ab_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/platformdirs-4.2.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/ply-3.11-py_1.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/proj-9.3.1-h1d62c97_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/prometheus_client-0.20.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/psutil-5.9.8-py310h2372a71_0.conda
# https://conda.anaconda.org/conda-forge/noarch/ptyprocess-0.7.0-pyhd3deb0d_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/pure_eval-0.2.2-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/pycparser-2.21-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pygments-2.17.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pyparsing-3.1.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/pyshp-2.3.1-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/pysocks-1.7.1-pyha2e5f31_6.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/python-fastjsonschema-2.19.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/python-tzdata-2024.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pytz-2024.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyyaml-6.0.1-py310h2372a71_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyzmq-24.0.1-py310h330234f_1.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/rpds-py-0.18.0-py310hcb5633a_0.conda
# https://conda.anaconda.org/conda-forge/noarch/send2trash-1.8.2-pyh41d4057_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/setuptools-69.1.0-pyhd8ed1ab_1.conda
# https://conda.anaconda.org/conda-forge/noarch/six-1.16.0-pyh6c4a22f_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/sniffio-1.3.0-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/sortedcontainers-2.4.0-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/soupsieve-2.5-pyhd8ed1ab_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/tblib-3.0.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/threadpoolctl-3.3.0-pyhc1e730c_0.conda
# https://conda.anaconda.org/conda-forge/noarch/toml-0.10.2-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/tomli-2.0.1-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/toolz-0.12.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/tornado-6.1-py310h5764c6d_3.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/traitlets-5.14.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/typing_extensions-4.9.0-pyha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/unicodedata2-15.1.0-py310h2372a71_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/wcwidth-0.2.13-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/webencodings-0.5.1-pyhd8ed1ab_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/websocket-client-1.7.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/wheel-0.42.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/widgetsnbextension-4.0.10-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xcb-util-image-0.4.0-h8ee46fc_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xkeyboard-config-2.41-hd590300_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/xorg-libxext-1.3.4-h0b41bf4_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/xorg-libxrender-0.9.11-hd590300_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/xyzservices-2023.10.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/zict-3.0.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/zipp-3.17.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/anyio-3.7.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/asttokens-2.4.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-auth-0.7.16-h70caa3e_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-mqtt-0.10.2-h0ef3971_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/beautifulsoup4-4.12.3-pyha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/bleach-6.1.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/cairo-1.18.0-h3faef2a_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/cffi-1.16.0-py310h2fee648_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/comm-0.2.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/cytoolz-0.12.3-py310h2372a71_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/fonttools-4.49.0-py310h2372a71_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/glib-2.78.4-hfc55251_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/importlib-metadata-7.0.1-pyha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/importlib_resources-6.1.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jedi-0.19.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jinja2-3.1.3-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/joblib-1.3.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/jupyter_core-5.7.1-py310hff52083_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jupyterlab_pygments-0.3.0-pyhd8ed1ab_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libcblas-3.9.0-21_linux64_openblas.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libclang-15.0.7-default_hb11cfb5_4.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libgoogle-cloud-2.12.0-hef10d8f_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/liblapack-3.9.0-21_linux64_openblas.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libnetcdf-4.9.2-nompi_h9612171_113.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libxkbcommon-1.6.0-hd429924_1.conda
# https://conda.anaconda.org/conda-forge/noarch/matplotlib-inline-0.1.6-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/partd-1.4.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pexpect-4.9.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pillow-10.2.0-py310h01dd4db_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pip-24.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/prompt-toolkit-3.0.42-pyha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pulseaudio-client-16.1-hb77b528_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyproj-3.6.1-py310hd5c30f3_5.conda
# https://conda.anaconda.org/conda-forge/noarch/python-dateutil-2.8.2-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/qtpy-2.4.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/referencing-0.33.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/sip-6.7.12-py310hc6cd4ac_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/terminado-0.18.0-pyh0d859eb_0.conda
# https://conda.anaconda.org/conda-forge/noarch/tinycss2-1.2.1-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/typing-extensions-4.9.0-hd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/urllib3-1.26.18-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/argon2-cffi-bindings-21.2.0-py310h2372a71_4.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-c-s3-0.5.1-h2910485_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/gstreamer-1.22.9-h98fc4e7_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/harfbuzz-8.3.0-h3d44ed6_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/importlib_metadata-7.0.1-hd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jsonschema-specifications-2023.12.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/jupyter_client-7.3.4-pyhd8ed1ab_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/numpy-1.26.4-py310hb13e2d6_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/prompt_toolkit-3.0.42-hd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyqt5-sip-12.12.2-py310hc6cd4ac_5.conda
# https://conda.anaconda.org/conda-forge/noarch/requests-2.31.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/stack_data-0.6.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/argon2-cffi-23.1.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-crt-cpp-0.26.2-ha623a59_3.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/bottleneck-1.3.7-py310h1f7b6fc_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/cftime-1.6.3-py310h1f7b6fc_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/contourpy-1.2.0-py310hd41b1e2_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/dask-core-2024.2.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/gst-plugins-base-1.22.9-h8e1006c_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/ipython-8.21.0-pyh707e725_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jsonschema-4.21.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pandas-2.2.0-py310hcc13569_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/patsy-0.5.6-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/scipy-1.12.0-py310hb13e2d6_2.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/shapely-2.0.3-py310hc3e127f_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/aws-sdk-cpp-1.11.267-h0bb408c_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/bokeh-3.3.4-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/distributed-2024.2.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/ipykernel-6.29.2-pyhd33586a_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/ipywidgets-8.1.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/linux-64/matplotlib-base-3.7.1-py310he60537e_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/nbformat-5.9.2-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/netcdf4-1.6.5-nompi_py310hba70d50_100.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/qt-main-5.15.8-h5810be5_19.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/scikit-learn-1.4.1.post1-py310h1fdf081_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/statsmodels-0.14.1-py310h1f7b6fc_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/xarray-2024.2.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/cartopy-0.22.0-py310hcc13569_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/iri-nextgen/noarch/cptio-1.2.0-py_0.tar.bz2
# https://conda.anaconda.org/conda-forge/noarch/jupyter_console-6.6.3-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-15.0.0-h49c8883_4_cpu.conda
# https://conda.anaconda.org/conda-forge/noarch/nbclient-0.8.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyqt-5.15.9-py310h04931ad_5.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/qtconsole-base-5.5.1-pyha770c72_0.conda
# https://conda.anaconda.org/iri-nextgen/noarch/cptcore-2.2.0-py_1.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/iri-nextgen/noarch/cptdl-1.1.5-py_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-acero-15.0.0-h59595ed_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-flight-15.0.0-hdc44a87_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-gandiva-15.0.0-h308e607_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libparquet-15.0.0-h352af49_4_cpu.conda
# https://conda.anaconda.org/conda-forge/linux-64/matplotlib-3.7.1-py310hff52083_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/nbconvert-core-7.16.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/iri-nextgen/noarch/cptextras-1.2.0-py_0.tar.bz2
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jupyter_server-1.24.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-dataset-15.0.0-h59595ed_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-flight-sql-15.0.0-hfbc7f12_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/nbconvert-pandoc-7.16.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/libarrow-substrait-15.0.0-hfbc7f12_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/nbconvert-7.16.1-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/notebook-shim-0.2.4-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/conda-forge/noarch/nbclassic-1.0.0-pyhb4ecaf3_1.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/linux-64/pyarrow-15.0.0-py310hf9e7431_4_cpu.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/notebook-6.5.6-pyha770c72_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/pyarrow-hotfix-0.6-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/dask-2024.2.0-pyhd8ed1ab_0.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/conda-forge/noarch/jupyter-1.0.0-pyhd8ed1ab_10.conda
# https://conda.anaconda.org/t/ir-777bcf3a-3147-44d2-9fa2-dccca9b8d3ed/iri-nextgen/noarch/pycpt-2.8.1-py_0.tar.bz2
